# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../archive (1)/2018.csv')

# %%
sns.boxplot(df['Happiness Score'])
# Out:
# <Axes: ylabel='Happiness Score'>
